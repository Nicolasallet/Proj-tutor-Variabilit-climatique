# %%
station=read.table(file ="data/stations.txt",sep=",", skip = 17,header = TRUE,quote="")
station
# Out:
#      STAID STANAME                                  CN LAT       LON
# 1     1    VAEXJOE                                  SE +56:52:00 +014:48:00
# 2     2    FALUN                                    SE +60:37:00 +015:37:00
# 3     3    STENSELE                                 SE +65:04:00 +017:09:59
# 4     4    LINKOEPING                               SE +58:24:00 +015:31:59
# 5     5    LINKOEPING-MALMSLAETT                    SE +58:24:00 +015:31:59
# 6     6    KARLSTAD                                 SE +59:21:00 +013:28:00
# 7     7    KARLSTAD-AIRPORT                         SE +59:26:40 +013:20:15
# 8     8    OESTERSUND                               SE +63:10:59 +014:28:59
# 9     9    OESTERSUND-FROESOEN                      SE +63:10:59 +014:28:59
# 10   10    STOCKHOLM                                SE +59:21:00 +018:03:00
# 11   11    KREMSMUENSTER (TAWES)                    AT +48:03:18 +014:07:51
# ...

# %%
List_sta= list("000031","000037","000173","000322","000749")
List_sta
# Out:
# [[1]]
# [1] "000031"
#
# [[2]]
# [1] "000037"
#
# [[3]]
# [1] "000173"
#
# [[4]]
# [1] "000322"
#
# [[5]]
# [1] "000749"

# %%
Liste_files_name = paste('data/TG_STAID',List_sta,".txt",sep="")
Liste_files_name
for (i in 1:length(Liste_files_name)){
    read.table(file=Liste_files_name[i],skip = 20,header=TRUE,sep=',')
}
# Out:
# [1] "data/TG_STAID000031.txt" "data/TG_STAID000037.txt"
# [3] "data/TG_STAID000173.txt" "data/TG_STAID000322.txt"
# [5] "data/TG_STAID000749.txt"
